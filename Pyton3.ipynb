# %% [markdown]
# <a href="https://colab.research.google.com/github/GiovannyMathUIS/Programacion1/blob/main/Pyton3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# List, tupla, conjunto y diccionario

# %%
Maduro = [1, 1, 2, 6, 7, 7, 4]
Pez = (1, 9, 7, 2, 2, 2)
HolaProfe = {1, 0, 9, 7, 9, 15, 3}
PorrasFiles = {
    "nombre": "porras",
    "p.apellido": "junior",
    "edad": "naneinf",
    "cargo": "director"}

# %%
Madurotupla = tuple(Maduro)
Madurodiccionario = dict(enumerate(Maduro))
Maduroconjunto = set(Maduro)

Pezlista = list(Pez)
Pezdiccionario = dict(enumerate(Pez))
Pezconjunto = set(Pez)

HolaProfelista = list(HolaProfe)
HolaProfetupla = tuple(HolaProfe)
HolaProfediccionario = dict(enumerate(HolaProfe))

PorrasFileslista = list(PorrasFiles.items())
PorrasFilestupla = tuple(PorrasFiles.items())
PorrasFilesconjunto = set(PorrasFiles.items())
